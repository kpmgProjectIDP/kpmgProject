# %%
import pandas as pd

# %%
df_commite = pd.read_csv('data/B/joint_committees.csv')

# %%
df_meta = pd.read_csv('data/B/CLA_meta_from_2018.csv')

# %%
df_combined = pd.read_csv('data/B/merge_committe_mega_Data.csv')

# %%
df_all = pd.read_csv('data/B/metadata_with_fr_nl_info.csv')

# %%
df_combined.head()
# Out:
#    Unnamed: 0  deposit_number  Nummer  \
# 0           0          175235   100.0
# 1           1          170873   100.0
# 2           2          172225   100.0
# 3           3          172224   100.0
# 4           4          172223   100.0
#
#                                       jc_name_fr  \
# 0  commission paritaire auxiliaire pour ouvriers
# 1  commission paritaire auxiliaire pour ouvriers
# 2  commission paritaire auxiliaire pour ouvriers
# 3  commission paritaire auxiliaire pour ouvriers
# 4  commission paritaire auxiliaire pour ouvriers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_fr  \
# 0                            Salaire horaire minimum
# ...

# %%
df_meta['cla_title_nl']
# Out:
# 0                                          Minimumuurloon
# 1                Sectoraal akkoord 2021-2022 - koopkracht
# 2       Vrijstelling van de verplichting van aangepast...
# 3                                  Tijdskrediet 2021-2022
# 4       Verhoging van de interne overurengrens en van ...
#                               ...
# 5686                                         landingsbaan
# 5687    aanwending van de bijdragen voor de risicogroe...
# 5688     procedure tot regeling van de sociale conflicten
# 5689    algemene classificatie en verloningsbeleid - w...
# 5690    wijziging van de statuten van het fonds voor b...
# Name: cla_title_nl, Length: 5691, dtype: object

# %%
filtered_df = df_meta[df_meta["cla_title_fr"].str.contains("Salaire")]

# %%
filtered_df.head()
# Out:
#      deposit_number  jc_number  \
# 0            175235      100.0
# 261          171558      105.0
# 512          175928      111.0
# 514          175246      111.0
# 535          172626      111.0
#
#                                             jc_name_fr  \
# 0        commission paritaire auxiliaire pour ouvriers
# 261        commission paritaire des metaux non-ferreux
# 512  commission paritaire des constructions metalli...
# 514  commission paritaire des constructions metalli...
# 535  commission paritaire des constructions metalli...
#
#                                             jc_name_nl  \
# 0        aanvullend paritair comite voor de werklieden
# 261          paritair comite voor de non-ferro metalen
# 512  paritair comite voor de metaal-, machine- en e...
# 514  paritair comite voor de metaal-, machine- en e...
# 535  paritair comite voor de metaal-, machine- en e...
#
#                               cla_title_fr                cla_title_nl  \
# ...

# %%
filtered_df.shape
# Out:
# (53, 26)

# %%
df_commite.head()
# Out:
#    joint_comittee_number                             joint_comittee_name_fr  \
# 0                 100.00      COMMISSION PARITAIRE AUXILIAIRE POUR OUVRIERS
# 1                 101.00               COMMISSION NATIONALE MIXTE DES MINES
# 2                 102.00  COMMISSION PARITAIRE DE L'INDUSTRIE DES CARRIERES
# 3                 102.01  SOUS-COMMISSION PARITAIRE DE L'INDUSTRIE DES C...
# 4                 102.02  SOUS-COMMISSION PARITAIRE DE L'INDUSTRIE DES C...
#
#                               joint_comittee_name_nl  \
# 0      AANVULLEND PARITAIR COMITE VOOR DE WERKLIEDEN
# 1                   NATIONALE GEMENGDE MIJNCOMMISSIE
# 2              PARITAIR COMITE VOOR HET GROEFBEDRIJF
# 3  PARITAIR SUBCOMITE VOOR HET BEDRIJF DER HARDST...
# 4  PARITAIR SUBCOMITE VOOR HET BEDRIJF DER HARDST...
#
#                               joint_comittee_name_de activity_end_date
# 0          PARITÄTISCHE HILFSKOMMISSION FÜR ARBEITER               NaN
# ...

# %%
df_meta.head()
# Out:
#    deposit_number  jc_number                                     jc_name_fr  \
# 0          175235      100.0  commission paritaire auxiliaire pour ouvriers
# 1          170873      100.0  commission paritaire auxiliaire pour ouvriers
# 2          172225      100.0  commission paritaire auxiliaire pour ouvriers
# 3          172224      100.0  commission paritaire auxiliaire pour ouvriers
# 4          172223      100.0  commission paritaire auxiliaire pour ouvriers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_fr  \
# 0                            Salaire horaire minimum
# 1       Accord sectoriel 2021-2022 - pouvoir dachat
# ...

# %%
df_meta.shape
# Out:
# (5691, 26)

# %%
df_meta.columns
# Out:
# Index(['deposit_number', 'jc_number', 'jc_name_fr', 'jc_name_nl',
#        'cla_title_fr', 'cla_title_nl', 'retrieve_date', 'label', 'themes_fr',
#        'themes_nl', 'signature_date', 'validity_date', 'deposit_date',
#        'record_date', 'deposit_reg_date', 'enforced', 'royal_decree_date',
#        'notice_depositMB_date', 'pub_roy_decree_date', 'corrected_date',
#        'filename', 'doc_size', 'scope_fr', 'scope_nl', 'no_scope_fr',
#        'no_scope_nl'],
#       dtype='object')

# %%
len(df_meta['jc_name_nl'].unique())
# Out:
# 151

# %%
df_meta['jc_name_nl'].value_counts()
# Out:
# paritair comite voor de voedingsnijverheid                                                                  204
# paritair comite voor de gezondheidsinrichtingen en -diensten                                                185
# paritair comite voor het vervoer en de logistiek                                                            169
# paritair comite voor de metaal-, machine- en elektrische bouw                                               118
# paritair comite voor de bedienden der metaalfabrikatennijverheid                                             97
#                                                                                                            ...
# paritair subcomite voor de verhuizing                                                                         2
# paritair comite voor de bedienden van de inrichtingen van het gesubsidieerd vrij onderwijs                    2
# ...

# %%
print('count: ',len(df_meta['cla_title_nl'].unique()))
df_meta['cla_title_nl'].value_counts()
# Out:
# count:  3443
# Coronapremie                                                                                        76
# Risicogroepen                                                                                       58
# Vrijstelling van de verplichting van aangepaste beschikbaarheid 2021-2022                           49
# Vrijstelling van de verplichting van aangepaste beschikbaarheid 2023-2024                           48
# loon- en arbeidsvoorwaarden                                                                         47
#                                                                                                     ..
# invulling van de loonnorm 2017-2018 voor de pakhuizen                                                1
# werkloosheid met bedrijfstoeslag 60 jaar                                                             1
# stelsel van werkloosheid met bedrijfstoeslag voor 2021-2022 - 59 jaar en 40 jaar beroepsverleden     1
# ...

# %%
print(len(df_meta['cla_title_nl'].unique()))
df_meta['cla_title_nl'].value_counts()
# Out:
# 3443
# Coronapremie                                                                                        76
# Risicogroepen                                                                                       58
# Vrijstelling van de verplichting van aangepaste beschikbaarheid 2021-2022                           49
# Vrijstelling van de verplichting van aangepaste beschikbaarheid 2023-2024                           48
# loon- en arbeidsvoorwaarden                                                                         47
#                                                                                                     ..
# invulling van de loonnorm 2017-2018 voor de pakhuizen                                                1
# werkloosheid met bedrijfstoeslag 60 jaar                                                             1
# stelsel van werkloosheid met bedrijfstoeslag voor 2021-2022 - 59 jaar en 40 jaar beroepsverleden     1
# ...

# %%
df_meta[df_meta['filename']== "100-2019-014381.pdf"]
# Out:
#     deposit_number  jc_number                                     jc_name_fr  \
# 29          155535      100.0  commission paritaire auxiliaire pour ouvriers
#
#                                        jc_name_nl cla_title_fr cla_title_nl  \
# 29  aanvullend paritair comite voor de werklieden   Formation.   Opleiding.
#
#    retrieve_date label                                          themes_fr  \
# 29    2022-12-07   new  formation (excl. formation syndicale)\formatio...
#
#                                             themes_nl  ... royal_decree_date  \
# 29  opleiding (excl. syndicale vorming)\opleiding ...  ...        2020-06-22
#
#    notice_depositMB_date pub_roy_decree_date corrected_date  \
# 29            2019-12-09          2020-08-03            NaN
#
#                filename  doc_size scope_fr scope_nl no_scope_fr no_scope_nl
# 29  100-2019-014381.pdf    101 Kb      NaN      NaN         NaN         NaN
#
# [1 rows x 26 columns]
